# %%
import requests as r

# %%
url='https://www.vinted.fr/api/v2/items?catalog_ids=1193&color_ids=&brand_ids=&size_ids=&material_ids=&status_ids=&country_ids=&city_ids=&is_for_swap=0&page=3&per_page=24&time=1606217681&search_session_id=1637457b-7c47-42dc-8ad4-86333438c8c8'

# %%
r.get(url)
# Out:
# <Response [401]>

# %%
headers="""accept: application/json, text/plain, */*
accept-encoding: gzip, deflate, br
accept-language: fr
cache-control: no-cache
cookie: __cfduid=dae2cc4044b101587922c88bb1bb0245d1606217373; anon_id=e02fab39-97d9-40d9-8201-52aed7dcece2; __cf_bm=d45eda13ce4ac937c01150e5f1f8be0ea0759d64-1606217380-1800-AbEjmVjmdk/343DINCDTq1gReUKRAwQOYXnEH4XhVEOHMiHz0mxQuQNcNCptUbCoSLWcKDCtx25cUkislIgp3Cp1FVWrXLUm4+ZmPZ1O1zW8Eh3CfymWfTC1MnCwywGH0N1bWv8jHdyNXQ0Unh4vpmDotQ+L8km/nPnlROJMvZbUR5XVzQ1R2fsF2HU5LX9+Ag==; G_ENABLED_IDPS=google; OptanonAlertBoxClosed=2020-11-24T11:29:44.131Z; eupubconsent-v2=CO9YVJUO9YVJUAcABBENBBCsAP_AAH_AAChQGXNf_X9fb2vj-_5999t0eY1f9_63t2wzjgeNs-8NyZ_X_J4XtmMyvB34pqYKmR4EunLBAQdlHGHcTQgAwIkVqTLsYk2MjzNKJ7JEilMbe2dYGH9vn8XT-ZKY70-v___7v3-_-___7pAy6BWABQAEQAKgAhgBFACYAFwAMwAjoBhAGHAMoAywBqADaAHhAPsA_ACAQEYARkAjgBIgCfAFLAKvAWgBaQC_AG8AOkAj0BIICYgEygJsAU2AsUBaIC2AFyALzAX0AwKBh4GIAMegZEBkYDLgEQQAIA-wC9ggCQAAUADgAPAAuAB8AHwASQAxAB_AEUAJEAZoA2gBxADkAHOAOoAf4BAwCDgEXAI0AT8AoYCHwEegJWATaAsIBaAC6AF1ALtAYgAxYBkIDKAkEoABAAC4AKAAqABkADgAHgAQAAiABUADQAHkAQwBEACYAE-...-_wCLAEYAI4ASkAq4BYoC0ALSAXMAvIBfgDCAGKANoAbiA6YDqAHoAQ2AiIBF4CQQEiAJUATYAnYBQ4CmgFWALFgWwBbIC4AFyALtAXeAwkBhoDDwGJAMYAY8AyQBk5ABEAAgAH4AQQAvgBoAD-AJEAW4AwgBlgDVAG0AOIAcgA5wB4AFLALEAYAA2QBvADtgIfAR6AlcBMQCbQFCgKQAUmArYBdAC-gGBEIGYACwAKAAZABEACoAGIAQwAmABVAC4AGIAMwAbwA9ACOAFiAMoAagA3wB3gD8AH-AQMAjABHACUgFDAKvAWgBaQC5gF--AGQANoAjgBIgC5AGEAMsAagA1wBtADiAHOAOoAdwA8ACAAEHAISARUAm0BPgE_AKWAWIAuoBgADFAGvAN4AdsA8gB_wEegJiATaApABTACpgFdgLQAXQAvoBgQDFikD4ABcAFAAVAAyABwAEAAKgAYgA0AB5AEMARAAmABPACkAFUALAAXAAxABmADmAIQAQ0AiACJAFKALEAW4AygBogDVAGyAO-AfYB-gEWAIwARwAlIBQwCrgFbALmAXkAwgBtADcAHoAReAkQBNgCdgFDgKaAVsAsUBbAC4AFyALtAYaAw8BjADIgGSAMnAA.f_gAD_gAAAAA; __gads=ID=ff1a60a6babafd80:T=1606217384:S=ALNI_MZXblLIXtQl1DMrA6i3hjGd6gaeRQ; domain_selected=true; _lm_id=B6GTUF4YGES0FAZ4; _gid=GA1.2.1200188717.1606217400; _fbp=fb.1.1606217400538.1810434889; _gcl_au=1.1.1838817939.1606217401; feature.expose.e02fab39-97d9-40d9-8201-52aed7dcece2=%5B%22sqp_ads%22%2C%22final_discovery_homepage%22%2C%22disable_boosts_for_new_buyers%22%2C%22location_city_country%22%2C%22nasa_delivery_instructions_redesign%22%5D; _gat=1; OptanonConsent=isIABGlobal=false&datestamp=Tue+Nov+24+2020+12%3A37%3A00+GMT%2B0100+(heure+normale+d%E2%80%99Europe+centrale)&version=6.7.0&hosts=&consentId=fac6b22b-9cfb-43dc-9698-2aeac023fcfb&interactionCount=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0002%3A1%2CC0003%3A1%2CC0004%3A1%2CSTACK42%3A1&geolocation=FR%3B&AwaitingReconsent=false; _vinted_fr_session=...--953f0bb6c70844055b98598c282e00dcce067112; _ga_ZJHK1N3D75=GS1.1.1606217400.1.1.1606217819.58; _ga=GA1.1.15444856.1606217400
pragma: no-cache
referer: https://www.vinted.fr/vetements?catalog[]=1193&time=1606217681&page=3
sec-fetch-dest: empty
sec-fetch-mode: cors
sec-fetch-site: same-origin
user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36
x-csrf-token: o8hos3+LUqjg1NXs3i13Ve/fCOcaSiJatFPCsk47a8+yXAku0bAoPcQiqsEESoAEqkwyNAtD1OxzWZz9hhXPYw=="""

# %%
headers=dict([i.split(': ') for i in headers.split('\n')])

# %%
response=r.get(url,headers=headers)

# %%
response

# %%
response.status_code
# Out:
# 200

# %%
response.text
# Out:
# '{"items":[{"id":728818477,"title":"Jeans ","brand_id":47,"size_id":633,"status_id":6,"disposal_conditions":4,"user_id":44595701,"owner_id":null,"country_id":16,"catalog_id":1560,"color1_id":3,"color2_id":null,"package_size_id":2,"is_hidden":0,"is_reserved":0,"reserved_for_user_id":null,"is_visible":1,"is_unisex":0,"is_closed":0,"is_admin_alerted":false,"active_bid_count":1,"favourite_count":1,"view_count":38,"moderation_status":0,"last_push_up_at":"2020-11-22T12:27:01+01:00","description":"Bonjour je vend un jean pour enfants \\n13/14  W34/24\\n\\n","package_size_standard":true,"item_closing_action":null,"related_catalog_ids":[],"related_catalogs_enabled":false,"size":"14 ans / 158-164 cm","brand":"Bonobo","composition":"","extra_conditions":"","is_for_sell":true,"is_for_swap":false,"is_for_give_away":false,"is_handicraft":false,"is_draft":false,"label":"Bonobo","real_value_numeric":null,"original_price_numeric":"22.0","price_numeric":"22.0","currency":"\\u20ac","created_at_ts":"202
# ...

# %%
data=response.json()

# %%
data.keys()
# Out:
# dict_keys(['items', 'item_scores_by_id', 'pagination', 'search_correlation_id', 'search_session_id', 'code'])

# %%
data['items']
# Out:
# [{'id': 728818477,
#   'title': 'Jeans ',
#   'brand_id': 47,
#   'size_id': 633,
#   'status_id': 6,
#   'disposal_conditions': 4,
#   'user_id': 44595701,
#   'owner_id': None,
#   'country_id': 16,
#   'catalog_id': 1560,
#   'color1_id': 3,
#   'color2_id': None,
#   'package_size_id': 2,
#   'is_hidden': 0,
#   'is_reserved': 0,
#   'reserved_for_user_id': None,
#   'is_visible': 1,
#   'is_unisex': 0,
#   'is_closed': 0,
#   'is_admin_alerted': False,
#   'active_bid_count': 1,
#   'favourite_count': 1,
#   'view_count': 38,
#   'moderation_status': 0,
#   'last_push_up_at': '2020-11-22T12:27:01+01:00',
#   'description': 'Bonjour je vend un jean pour enfants \n13/14  W34/24\n\n',
#   'package_size_standard': True,
#   'item_closing_action': None,
#   'related_catalog_ids': [],
#   'related_catalogs_enabled': False,
#   'size': '14 ans / 158-164 cm',
#   'brand': 'Bonobo',
#   'composition': '',
#   'extra_conditions': '',
#   'is_for_sell': True,
#   'is_for_swap': False,
# ...

# %%
import pandas as pd
pd.json_normalize(data['items'])
# Out:
#            id                                              title  brand_id  \
# 0   728818477                                             Jeans         47
# 1   755233924                      Habillage nouveau né babyzen     309757
# 2   749040163                                        Lot t.6ans         60
# 3   746622880                                       2017 127/250    315251
# 4   755224821                                    Blouson de ski      13813
# 5   752276351                                    Lots vêtement      174022
# 6   737572627                                       Blazers gris     13743
# 7   728074609                                     Nancy comunion    320410
# 8   751755795                                     Storio max 2.0    274487
# 9   746148530                                       Veste t.8ans         1
# 10  737982490                                  Siège auto Britax         1
# ...

# %%
df=pd.json_normalize(data['items'])
