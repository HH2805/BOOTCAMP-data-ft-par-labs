# %%
import requests as r

# %%
#Request url de la page 3 de Vinted - hommes, manteaux
url='https://www.vinted.fr/api/v2/items?catalog_ids=1206&color_ids=&brand_ids=&size_ids=&material_ids=&status_ids=&country_ids=&city_ids=&is_for_swap=0&page=3&per_page=24&time=1606574071&search_session_id=cf504484-be69-46a8-b108-56f06e2c4ea7'

# %%
r.get(url)
# Out:
# <Response [401]>

# %%
headers="""accept: application/json, text/plain, */*
accept-encoding: gzip, deflate, br
accept-language: fr
cache-control: no-cache
cookie: __cfduid=d4d35af4319a437b4de2f4cb59534917c1606417476; G_ENABLED_IDPS=google; OptanonAlertBoxClosed=2020-11-26T19:07:09.395Z; eupubconsent-v2=CO9f-BWO9f-BWAcABBENBBCsAP_AAH_AAChQGXNf_X9fb2vj-_5999t0eY1f9_63t2wzjgeNs-8NyZ_X_J4XtmMyvB34pqYKmR4EunLBAQdlHGHcTQgAwIkVqTLsYk2MjzNKJ7JEilMbe2dYGH9vn8XT-ZKY70-v___7v3-_-___7pAy6BWABQAEQAKgAhgBFACYAFwAMwAjoBhAGHAMoAywBqADaAHhAPsA_ACAQEYARkAjgBIgCfAFLAKvAWgBaQC_AG8AOkAj0BIICYgEygJsAU2AsUBaIC2AFyALzAX0AwKBh4GIAMegZEBkYDLgEQQAIA-wC9ggCQAAUADgAPAAuAB8AHwASQAxAB_AEUAJEAZoA2gBxADkAHOAOoAf4BAwCDgEXAI0AT8AoYCHwEegJWATaAsIBaAC6AF1ALtAYgAxYBkIDKAkEoABAAC4AKAAqABkADgAHgAQAAiABUADQAHkAQwBEACYAE-...-_wCLAEYAI4ASkAq4BYoC0ALSAXMAvIBfgDCAGKANoAbiA6YDqAHoAQ2AiIBF4CQQEiAJUATYAnYBQ4CmgFWALFgWwBbIC4AFyALtAXeAwkBhoDDwGJAMYAY8AyQBk5ABEAAgAH4AQQAvgBoAD-AJEAW4AwgBlgDVAG0AOIAcgA5wB4AFLALEAYAA2QBvADtgIfAR6AlcBMQCbQFCgKQAUmArYBdAC-gGBEIGYACwAKAAZABEACoAGIAQwAmABVAC4AGIAMwAbwA9ACOAFiAMoAagA3wB3gD8AH-AQMAjABHACUgFDAKvAWgBaQC5gF--AGQANoAjgBIgC5AGEAMsAagA1wBtADiAHOAOoAdwA8ACAAEHAISARUAm0BPgE_AKWAWIAuoBgADFAGvAN4AdsA8gB_wEegJiATaApABTACpgFdgLQAXQAvoBgQDFikD4ABcAFAAVAAyABwAEAAKgAYgA0AB5AEMARAAmABPACkAFUALAAXAAxABmADmAIQAQ0AiACJAFKALEAW4AygBogDVAGyAO-AfYB-gEWAIwARwAlIBQwCrgFbALmAXkAwgBtADcAHoAReAkQBNgCdgFDgKaAVsAsUBbAC4AFyALtAYaAw8BjADIgGSAMnAA.f_gAD_gAAAAA; _lm_id=17XGOHPBCGZ09A8H; _gcl_au=1.1.1753118879.1606417639; _fbp=fb.1.1606417639202.943446011; __gads=ID=8be4fc5c724de7c8:T=1606417639:S=ALNI_MamPzmQYatVS3Qa8dP_IOE-3stU_Q; domain_selected=true; gadsTest=test; _gid=GA1.2.1546462004.1606555160; anon_id=327f6f1c-2329-44a8-a4cd-037a217762fc; last_user_id=17549705; _ga=GA1.1.820534410.1606417639; push_up_value_proposition_shown=true; _gcl_aw=GCL.1606561063.Cj0KCQiAh4j-BRCsARIsAGeV12DBSBVOSkVA_i1QHrWjYDirBftTXyWs_1Synbk3GuDqw-ZjqwyKt-waAlIxEALw_wcB; seller_header_visits=3; __cf_bm=b85cb3eb5a8f417d2b039cd6300a3277d8244faf-1606574066-1800-AavRSHgmBhNTiPdthgFaqpRT3aFNlA2PFkEbCTuIN//DiFDsYs98R1jypnuglqJIli9RnNNitpINrDAiAj8KSvsjhPCtrW71TigbTPZEUf59255mjeE9iM1jdEatT0c5zZTLqs6h7FqyR4JLDm0Pq03IfMZCJaYnGGTVlDemFLq38NJChAm4W4qoPr2vkKgMnQ==; feature.expose.327f6f1c-2329-44a8-a4cd-037a217762fc=%5B%22sqp_ads%22%2C%22nasa_delivery_instructions_redesign%22%2C%22final_discovery_homepage%22%2C%22disable_boosts_for_new_buyers%22%2C%22unsuccessful_seller_boost_weight%22%2C%22content_autotranslation%22%2C%22location_city_country%22%5D; OptanonConsent=isIABGlobal=false&datestamp=Sat+Nov+28+2020+15%3A34%3A34+GMT%2B0100+(heure+normale+d%E2%80%99Europe+centrale)&version=6.7.0&hosts=&consentId=3da64186-3e6c-48f4-8d3c-904d183600e5&interactionCount=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0002%3A1%2CC0003%3A1%2CC0004%3A1%2CSTACK42%3A1&geolocation=FR%3B&AwaitingReconsent=false; _vinted_fr_session=...%3D--a8849501f86f689ad62f532f97384dff59fab0e2; _ga_ZJHK1N3D75=GS1.1.1606574065.5.1.1606574081.44
pragma: no-cache
referer: https://www.vinted.fr/vetements?catalog[]=1206&time=1606574071&page=3
sec-fetch-dest: empty
sec-fetch-mode: cors
sec-fetch-site: same-origin
user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36
x-csrf-token: hXrRU5sbaNvWKM8lp1ujtGpSBP90eRL5Q8Zt3Pn0tbz4Usf6ygwfYDnTHVdzrql0GKyPPq7cGCkeIZAqmhhWEg=="""

# %%
headers=dict([i.split(': ') for i in headers.split('\n')])

# %%
response=r.get(url,headers=headers)
response
# Out:
# <Response [200]>

# %%
response.status_code
# Out:
# 200

# %%
response.text
# Out:
# '{"items":[{"id":759800031,"title":"Veste militaire XL kaki","brand_id":14867,"size_id":210,"status_id":4,"disposal_conditions":4,"user_id":45852098,"owner_id":null,"country_id":16,"catalog_id":1856,"color1_id":16,"color2_id":null,"package_size_id":2,"is_hidden":0,"is_reserved":0,"reserved_for_user_id":null,"is_visible":1,"is_unisex":0,"is_closed":0,"is_admin_alerted":false,"active_bid_count":0,"favourite_count":7,"view_count":91,"moderation_status":0,"last_push_up_at":"2020-11-28T11:29:14+01:00","description":"Véritable veste militaire couleur kaki des années 60 de type \\"M65\\", \\"field jacket\\" ou \\"jungle jacket\\".\\n\\nCordon de serrage à l\'intérieur de la veste permettant d\'ajuster le cintrage.\\n\\nLargeur d\'ouverture des manches réglable via un système de bouton.\\n\\nVeste tendance qui s\'associe facilement dans un look workwear/décontracté avec un t-shirt blanc ou une chemise en denim, ou encore dans un look plus habillé par dessus un col roulé par exemple, comme su
# ...

# %%
data=response.json()
data
# Out:
# {'items': [{'id': 759800031,
#    'title': 'Veste militaire XL kaki',
#    'brand_id': 14867,
#    'size_id': 210,
#    'status_id': 4,
#    'disposal_conditions': 4,
#    'user_id': 45852098,
#    'owner_id': None,
#    'country_id': 16,
#    'catalog_id': 1856,
#    'color1_id': 16,
#    'color2_id': None,
#    'package_size_id': 2,
#    'is_hidden': 0,
#    'is_reserved': 0,
#    'reserved_for_user_id': None,
#    'is_visible': 1,
#    'is_unisex': 0,
#    'is_closed': 0,
#    'is_admin_alerted': False,
#    'active_bid_count': 0,
#    'favourite_count': 7,
#    'view_count': 91,
#    'moderation_status': 0,
#    'last_push_up_at': '2020-11-28T11:29:14+01:00',
# ...

# %%
data.keys()
# Out:
# dict_keys(['items', 'item_scores_by_id', 'pagination', 'search_correlation_id', 'search_session_id', 'code'])

# %%
data['items']
# Out:
# [{'id': 759800031,
#   'title': 'Veste militaire XL kaki',
#   'brand_id': 14867,
#   'size_id': 210,
#   'status_id': 4,
#   'disposal_conditions': 4,
#   'user_id': 45852098,
#   'owner_id': None,
#   'country_id': 16,
#   'catalog_id': 1856,
#   'color1_id': 16,
#   'color2_id': None,
#   'package_size_id': 2,
#   'is_hidden': 0,
#   'is_reserved': 0,
#   'reserved_for_user_id': None,
#   'is_visible': 1,
#   'is_unisex': 0,
#   'is_closed': 0,
#   'is_admin_alerted': False,
#   'active_bid_count': 0,
#   'favourite_count': 7,
#   'view_count': 91,
#   'moderation_status': 0,
#   'last_push_up_at': '2020-11-28T11:29:14+01:00',
# ...

# %%
import pandas as pd
pd.json_normalize(data['items'])
# Out:
#            id                                              title  brand_id  \
# 0   759800031                            Veste militaire XL kaki     14867
# 1   758909645                            Blauwe jas Michael Kors      6005
# 2   762840392                                   Abrigo Hugo Boss     25383
# 3   762869492                                  Doudoune Pyrenex      19741
# 4   757888058                               Chupa Jack and Jones     36955
# 5   755802413                          Leren jas Hilfiger maat L        94
# 6   764982663                               Veste en jean clair      11493
# 7   756789316                            Veste The Kooples Sport      2021
# 8   757738234                           Palm angles denim jacket    395367
# 9   759541731                                    Manteau Sandro        115
# 10  758298982                                   Blouson Lacoste        304
# ...

# %%
#Request url de la page 4 de Vinted - hommes, manteaux
"https://www.vinted.fr/api/v2/items?catalog_ids=1206&color_ids=&brand_ids=&size_ids=&material_ids=&status_ids=&country_ids=&city_ids=&is_for_swap=0&page=4&per_page=24&time=1606574071&search_session_id=cf504484-be69-46a8-b108-56f06e2c4ea"
# Out:
# 'https://www.vinted.fr/api/v2/items?catalog_ids=1206&color_ids=&brand_ids=&size_ids=&material_ids=&status_ids=&country_ids=&city_ids=&is_for_swap=0&page=4&per_page=24&time=1606574071&search_session_id=cf504484-be69-46a8-b108-56f06e2c4ea\u200b'

# %%
#Pour extraire les données de toutes les pages de Vinted - hommes, manteaux

df_final=pd.DataFrame()
for i in range(1,6):
    url=f'https://www.vinted.fr/api/v2/items?catalog_ids=1206&color_ids=&brand_ids=&size_ids=&material_ids=&status_ids=&country_ids=&city_ids=&is_for_swap=0&page={i}&per_page=24&time=1606574071&search_session_id=cf504484-be69-46a8-b108-56f06e2c4ea'
    headers=f"""accept: application/json, text/plain, */*
accept-encoding: gzip, deflate, br
accept-language: fr
cache-control: no-cache
cookie: __cfduid=d4d35af4319a437b4de2f4cb59534917c1606417476; G_ENABLED_IDPS=google; OptanonAlertBoxClosed=2020-11-26T19:07:09.395Z; eupubconsent-v2=CO9f-BWO9f-BWAcABBENBBCsAP_AAH_AAChQGXNf_X9fb2vj-_5999t0eY1f9_63t2wzjgeNs-8NyZ_X_J4XtmMyvB34pqYKmR4EunLBAQdlHGHcTQgAwIkVqTLsYk2MjzNKJ7JEilMbe2dYGH9vn8XT-ZKY70-v___7v3-_-___7pAy6BWABQAEQAKgAhgBFACYAFwAMwAjoBhAGHAMoAywBqADaAHhAPsA_ACAQEYARkAjgBIgCfAFLAKvAWgBaQC_AG8AOkAj0BIICYgEygJsAU2AsUBaIC2AFyALzAX0AwKBh4GIAMegZEBkYDLgEQQAIA-wC9ggCQAAUADgAPAAuAB8AHwASQAxAB_AEUAJEAZoA2gBxADkAHOAOoAf4BAwCDgEXAI0AT8AoYCHwEegJWATaAsIBaAC6AF1ALtAYgAxYBkIDKAkEoABAAC4AKAAqABkADgAHgAQAAiABUADQAHkAQwBEACYAE-...-_wCLAEYAI4ASkAq4BYoC0ALSAXMAvIBfgDCAGKANoAbiA6YDqAHoAQ2AiIBF4CQQEiAJUATYAnYBQ4CmgFWALFgWwBbIC4AFyALtAXeAwkBhoDDwGJAMYAY8AyQBk5ABEAAgAH4AQQAvgBoAD-AJEAW4AwgBlgDVAG0AOIAcgA5wB4AFLALEAYAA2QBvADtgIfAR6AlcBMQCbQFCgKQAUmArYBdAC-gGBEIGYACwAKAAZABEACoAGIAQwAmABVAC4AGIAMwAbwA9ACOAFiAMoAagA3wB3gD8AH-AQMAjABHACUgFDAKvAWgBaQC5gF--AGQANoAjgBIgC5AGEAMsAagA1wBtADiAHOAOoAdwA8ACAAEHAISARUAm0BPgE_AKWAWIAuoBgADFAGvAN4AdsA8gB_wEegJiATaApABTACpgFdgLQAXQAvoBgQDFikD4ABcAFAAVAAyABwAEAAKgAYgA0AB5AEMARAAmABPACkAFUALAAXAAxABmADmAIQAQ0AiACJAFKALEAW4AygBogDVAGyAO-AfYB-gEWAIwARwAlIBQwCrgFbALmAXkAwgBtADcAHoAReAkQBNgCdgFDgKaAVsAsUBbAC4AFyALtAYaAw8BjADIgGSAMnAA.f_gAD_gAAAAA; _lm_id=17XGOHPBCGZ09A8H; _gcl_au=1.1.1753118879.1606417639; _fbp=fb.1.1606417639202.943446011; __gads=ID=8be4fc5c724de7c8:T=1606417639:S=ALNI_MamPzmQYatVS3Qa8dP_IOE-3stU_Q; domain_selected=true; gadsTest=test; _gid=GA1.2.1546462004.1606555160; anon_id=327f6f1c-2329-44a8-a4cd-037a217762fc; last_user_id=17549705; _ga=GA1.1.820534410.1606417639; push_up_value_proposition_shown=true; _gcl_aw=GCL.1606561063.Cj0KCQiAh4j-BRCsARIsAGeV12DBSBVOSkVA_i1QHrWjYDirBftTXyWs_1Synbk3GuDqw-ZjqwyKt-waAlIxEALw_wcB; seller_header_visits=3; __cf_bm=b85cb3eb5a8f417d2b039cd6300a3277d8244faf-1606574066-1800-AavRSHgmBhNTiPdthgFaqpRT3aFNlA2PFkEbCTuIN//DiFDsYs98R1jypnuglqJIli9RnNNitpINrDAiAj8KSvsjhPCtrW71TigbTPZEUf59255mjeE9iM1jdEatT0c5zZTLqs6h7FqyR4JLDm0Pq03IfMZCJaYnGGTVlDemFLq38NJChAm4W4qoPr2vkKgMnQ==; feature.expose.327f6f1c-2329-44a8-a4cd-037a217762fc=%5B%22sqp_ads%22%2C%22nasa_delivery_instructions_redesign%22%2C%22final_discovery_homepage%22%2C%22disable_boosts_for_new_buyers%22%2C%22unsuccessful_seller_boost_weight%22%2C%22content_autotranslation%22%2C%22location_city_country%22%5D; OptanonConsent=isIABGlobal=false&datestamp=Sat+Nov+28+2020+15%3A34%3A34+GMT%2B0100+(heure+normale+d%E2%80%99Europe+centrale)&version=6.7.0&hosts=&consentId=3da64186-3e6c-48f4-8d3c-904d183600e5&interactionCount=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0002%3A1%2CC0003%3A1%2CC0004%3A1%2CSTACK42%3A1&geolocation=FR%3B&AwaitingReconsent=false; _vinted_fr_session=...%3D--a8849501f86f689ad62f532f97384dff59fab0e2; _ga_ZJHK1N3D75=GS1.1.1606574065.5.1.1606574081.44
pragma: no-cache
referer: https://www.vinted.fr/vetements?catalog[]=1206&time=1606574071&page={i}
sec-fetch-dest: empty
sec-fetch-mode: cors
sec-fetch-site: same-origin
user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36
x-csrf-token: hXrRU5sbaNvWKM8lp1ujtGpSBP90eRL5Q8Zt3Pn0tbz4Usf6ygwfYDnTHVdzrql0GKyPPq7cGCkeIZAqmhhWEg=="""
    headers=dict([i.split(': ') for i in headers.split('\n')])    
    response=r.get(url, headers=headers)
    data=response.json()
    df=pd.json_normalize(data['items'])
    df_final=df_final.append(df)
    print('page number',i,'is done!')
# Out:
# page number 1 is done!
# page number 2 is done!
# page number 3 is done!
# page number 4 is done!
# page number 5 is done!

# %%
df_final
# Out:
#            id                                              title  brand_id  \
# 0   765251041                          Chaqueta Belstaff de piel    131166
# 1   756979938                    Carhartt Sheffield Jacket Veste    288034
# 2   761251372                    Blouson aviateur avirex USA NYC      4565
# 3   756093724                     Blouson Redskins Cuir taille L      7009
# 4   762328057                           Ultralight Bomber Jacket      5879
# ..        ...                                                ...       ...
# 19  762139067                                Blouson homme noir      14867
# 20  760124061                       Chaqueta docker con poco uso    406370
# 21  757738235  Manteau Parka Tommy Hilfiger Camo neuf jamais ...        94
# 22  764610237                        Veste matelassée kaki homme         1
# 23  766405245                                        Veste Zara      45969
#
# ...

# %%
df_final.drop_duplicates(subset=['id'])
# Out:
#            id                                              title  brand_id  \
# 0   765251041                          Chaqueta Belstaff de piel    131166
# 1   756979938                    Carhartt Sheffield Jacket Veste    288034
# 2   761251372                    Blouson aviateur avirex USA NYC      4565
# 3   756093724                     Blouson Redskins Cuir taille L      7009
# 4   762328057                           Ultralight Bomber Jacket      5879
# ..        ...                                                ...       ...
# 19  762139067                                Blouson homme noir      14867
# 20  760124061                       Chaqueta docker con poco uso    406370
# 21  757738235  Manteau Parka Tommy Hilfiger Camo neuf jamais ...        94
# 22  764610237                        Veste matelassée kaki homme         1
# 23  766405245                                        Veste Zara      45969
#
# ...
